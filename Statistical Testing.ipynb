# %%
import numpy as np
import pandas as pd
import seaborn as sns
from statsmodels.formula.api import ols
import statsmodels.api as sm
from scipy.stats import chi2_contingency

# %%
data = pd.read_csv('smoking.csv')
data.head()
# Out:
#    ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0      F   40         155          60       81.3             1.2
# 1   1      F   40         160          60       81.0             0.8
# 2   2      M   55         170          60       80.0             0.8
# 3   3      M   40         165          70       88.0             1.5
# 4   4      F   40         155          60       86.0             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  ...  hemoglobin  \
# 0              1.0            1.0             1.0  ...        12.9
# 1              0.6            1.0             1.0  ...        12.7
# 2              0.8            1.0             1.0  ...        15.8
# 3              1.5            1.0             1.0  ...        14.7
# 4              1.0            1.0             1.0  ...        12.5
#
#    Urine protein  serum creatinine   AST   ALT   Gtp  oral  dental caries  \
# ...

# %%
data.rename(columns={'height(cm)': 'height', 'weight(kg)' : 'weight', 'waist(cm)' : 'waist', 'eyesight(left)' : 'eyesightleft', 'eyesight(right)' : 'eyesightright', 
                     'hearing(left)' : 'hearingleft', 'hearing(right)' : 'hearingright', 'fasting blood sugar' : 'fastingbloodsugar',
                    'Urine protein' : 'urineprotein', 'serum creatinine' : 'serumcreatinine', 'dental caries' : 'dentalcaries'}, inplace=True)
data.head()
# Out:
#    ID gender  age  height  weight  waist  eyesightleft  eyesightright  \
# 0   0      F   40     155      60   81.3           1.2            1.0
# 1   1      F   40     160      60   81.0           0.8            0.6
# 2   2      M   55     170      60   80.0           0.8            0.8
# 3   3      M   40     165      70   88.0           1.5            1.5
# 4   4      F   40     155      60   86.0           1.0            1.0
#
#    hearingleft  hearingright  ...  hemoglobin  urineprotein  serumcreatinine  \
# 0          1.0           1.0  ...        12.9           1.0              0.7
# 1          1.0           1.0  ...        12.7           1.0              0.6
# 2          1.0           1.0  ...        15.8           1.0              1.0
# 3          1.0           1.0  ...        14.7           1.0              1.0
# 4          1.0           1.0  ...        12.5           1.0              0.6
#
#     AST   ALT   Gtp  oral  dentalcaries  tartar  smoking
# ...

# %%
#ANOVA test
model = ols('age ~ smoking', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                 sum_sq       df            F  PR(>F)
# smoking   2.144429e+05      1.0  1511.533598     0.0
# Residual  7.900801e+06  55690.0          NaN     NaN

# %%
model = ols('height ~ smoking', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                 sum_sq       df             F  PR(>F)
# smoking   7.408336e+05      1.0  10399.223169     0.0
# Residual  3.967318e+06  55690.0           NaN     NaN

# %%
model = ols('weight ~ smoking', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                 sum_sq       df            F  PR(>F)
# smoking   8.391431e+05      1.0  5620.701741     0.0
# Residual  8.314243e+06  55690.0          NaN     NaN

# %%
model = ols('waist ~ smoking', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                 sum_sq       df            F  PR(>F)
# smoking   2.452183e+05      1.0  3004.777441     0.0
# Residual  4.544832e+06  55690.0          NaN     NaN

# %%
model = ols('eyesightleft ~ smoking', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                 sum_sq       df           F        PR(>F)
# smoking      49.450497      1.0  209.392369  2.272557e-47
# Residual  13151.855535  55690.0         NaN           NaN

# %%
model = ols('eyesightright ~ smoking', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                 sum_sq       df           F        PR(>F)
# smoking      52.228336      1.0  222.033001  4.070650e-50
# Residual  13099.836656  55690.0         NaN           NaN

# %%
model = ols('hearingleft ~ smoking', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#               sum_sq       df          F        PR(>F)
# smoking      0.74792      1.0  30.012925  4.310291e-08
# Residual  1387.79038  55690.0        NaN           NaN

# %%
model = ols('hearingright ~ smoking', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                sum_sq       df          F    PR(>F)
# smoking      0.504090      1.0  19.805388  0.000009
# Residual  1417.430551  55690.0        NaN       NaN

# %%
model = ols('systolic ~ smoking', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                 sum_sq       df           F        PR(>F)
# smoking   5.567356e+04      1.0  299.261728  7.140976e-67
# Residual  1.036036e+07  55690.0         NaN           NaN

# %%
model = ols('relaxation ~ smoking', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                 sum_sq       df           F         PR(>F)
# smoking   6.120728e+04      1.0  661.049767  6.221085e-145
# Residual  5.156394e+06  55690.0         NaN            NaN

# %%
model = ols('fastingbloodsugar ~ smoking', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                 sum_sq       df           F         PR(>F)
# smoking   2.421831e+05      1.0  565.695615  2.030200e-124
# Residual  2.384176e+07  55690.0         NaN            NaN

# %%
model = ols('Cholesterol ~ smoking', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                 sum_sq       df          F        PR(>F)
# smoking   5.979926e+04      1.0  45.423244  1.602803e-11
# Residual  7.331535e+07  55690.0        NaN           NaN

# %%
model = ols('triglyceride ~ smoking', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                 sum_sq       df           F  PR(>F)
# smoking   1.812183e+07      1.0  3769.92325     0.0
# Residual  2.676990e+08  55690.0         NaN     NaN

# %%
model = ols('HDL ~ smoking', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                 sum_sq       df            F  PR(>F)
# smoking   3.853456e+05      1.0  1832.174487     0.0
# Residual  1.171280e+07  55690.0          NaN     NaN

# %%
model = ols('LDL ~ smoking', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                 sum_sq       df           F        PR(>F)
# smoking   1.907481e+05      1.0  114.112366  1.306645e-26
# Residual  9.309037e+07  55690.0         NaN           NaN

# %%
model = ols('hemoglobin ~ smoking', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                  sum_sq       df             F  PR(>F)
# smoking    21883.933651      1.0  10650.466395     0.0
# Residual  114428.440952  55690.0           NaN     NaN

# %%
model = ols('urineprotein ~ smoking', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                sum_sq       df          F   PR(>F)
# smoking      1.858317      1.0  11.338162  0.00076
# Residual  9127.553932  55690.0        NaN      NaN

# %%
model = ols('serumcreatinine ~ smoking', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                sum_sq       df            F  PR(>F)
# smoking    128.467873      1.0  2746.977732     0.0
# Residual  2604.453525  55690.0          NaN     NaN

# %%
model = ols('AST ~ smoking', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                 sum_sq       df           F        PR(>F)
# smoking   7.325137e+04      1.0  196.213305  1.666700e-44
# Residual  2.079048e+07  55690.0         NaN           NaN

# %%
model = ols('ALT ~ smoking', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                 sum_sq       df           F         PR(>F)
# smoking   5.053714e+05      1.0  532.692089  2.612509e-117
# Residual  5.283378e+07  55690.0         NaN            NaN

# %%
model = ols('Gtp ~ smoking', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                 sum_sq       df            F  PR(>F)
# smoking   7.885996e+06      1.0  3302.926214     0.0
# Residual  1.329642e+08  55690.0          NaN     NaN

# %%
lst = ['age', 'height', 'weight']

for item in lst:
    mod = ols('{} ~ smoking'.format(item), data= data).fit()
    aov_table = sm.stats.anova_lm(mod, typ=2)
    print(aov_table)
# Out:
#                 sum_sq       df            F  PR(>F)
# smoking   2.144429e+05      1.0  1511.533598     0.0
# Residual  7.900801e+06  55690.0          NaN     NaN
#                 sum_sq       df             F  PR(>F)
# smoking   7.408336e+05      1.0  10399.223169     0.0
# Residual  3.967318e+06  55690.0           NaN     NaN
#                 sum_sq       df            F  PR(>F)
# smoking   8.391431e+05      1.0  5620.701741     0.0
# Residual  8.314243e+06  55690.0          NaN     NaN

# %%
data = ['oral']
stat, p, dof, expected = chi2_contingency(data)
alpha = np.int64(0.05)
print("p value is " + str(p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (H0 holds true)')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [25], in <cell line: 2>()
#       1 data = ['oral']
# ----> 2 stat, p, dof, expected = chi2_contingency(data)
#       3 alpha = np.int64(0.05)
#       4 print("p value is " + str(p))
#
# File ~\anaconda3\lib\site-packages\scipy\stats\contingency.py:266, in chi2_contingency(observed, correction, lambda_)
#     133 """Chi-square test of independence of variables in a contingency table.
#     134
#     135 This function computes the chi-square statistic and p-value for the
#    (...)
#     263           [ 18.10873492,  18.10873492]]]]))
#     264 """
#     265 observed = np.asarray(observed)
# --> 266 if np.any(observed < 0):
#     267     raise ValueError("All values in `observed` must be nonnegative.")
#     268 if observed.size == 0:
#
# TypeError: '<' not supported between instances of 'numpy.ndarray' and 'int'

# %%
chisqt = pd.crosstab(data.gender, data.oral, margins=True)
value = np.array([chisqt.iloc[0][0:5].values,
                  chisqt.iloc[1][0:5].values])
print(chi2_contingency(value)[0:3])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 chisqt = pd.crosstab(data.gender, data.oral, margins=True)
#       2 value = np.array([chisqt.iloc[0][0:5].values,
#       3                   chisqt.iloc[1][0:5].values])
#       4 print(chi2_contingency(value)[0:3])
#
# AttributeError: 'list' object has no attribute 'gender'
